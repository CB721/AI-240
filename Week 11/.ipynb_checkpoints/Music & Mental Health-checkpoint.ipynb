# %%
import pandas as pd
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Exploration

# %%
data = pd.read_csv("dataset.csv")
data.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 1                No  ...        Sometimes           Rarely  Very frequently
# 2               Yes  ...            Never           Rarely           Rarely
# 3               Yes  ...        Sometimes            Never            Never
# 4                No  ...  Very frequently  Very frequently            Never
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# 0                    Sometimes     3.0        0.0      1.0  0.0           NaN
# 1                       Rarely     7.0        2.0      2.0  1.0           NaN
# 2              Very frequently     7.0        7.0     10.0  2.0     No effect
# 3                        Never     9.0        7.0      3.0  3.0       Improve
# 4                       Rarely     7.0        2.0      5.0  9.0       Improve
#
#      Permissions
# 0  I understand.
# 1  I understand.
# 2  I understand.
# 3  I understand.
# 4  I understand.
#
# [5 rows x 33 columns]

# %%
data.shape
# Out:
# (736, 33)

# %%
data['Music effects'].value_counts()
# Out:
# Music effects
# Improve      542
# No effect    169
# Worsen        17
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
#  12  Frequency [Country]           736 non-null    object
#  13  Frequency [EDM]               736 non-null    object
#  14  Frequency [Folk]              736 non-null    object
#  15  Frequency [Gospel]            736 non-null    object
#  16  Frequency [Hip hop]           736 non-null    object
#  17  Frequency [Jazz]              736 non-null    object
#  18  Frequency [K pop]             736 non-null    object
#  19  Frequency [Latin]             736 non-null    object
#  20  Frequency [Lofi]              736 non-null    object
#  21  Frequency [Metal]             736 non-null    object
#  22  Frequency [Pop]               736 non-null    object
#  23  Frequency [R&B]               736 non-null    object
#  24  Frequency [Rap]               736 non-null    object
#  25  Frequency [Rock]              736 non-null    object
#  26  Frequency [Video game music]  736 non-null    object
#  27  Anxiety                       736 non-null    float64
#  28  Depression                    736 non-null    float64
#  29  Insomnia                      736 non-null    float64
#  30  OCD                           736 non-null    float64
#  31  Music effects                 728 non-null    object
#  32  Permissions                   736 non-null    object
# dtypes: float64(7), object(26)
# memory usage: 189.9+ KB

# %% [markdown]
# # Data Preprocessing

# %%
null_counts = data.isnull().sum()
print("Null counts")
null_counts[null_counts > 0]
# Out:
# Null counts
# Age                            1
# Primary streaming service      1
# While working                  3
# Instrumentalist                4
# Composer                       1
# Foreign languages              4
# BPM                          107
# Music effects                  8
# dtype: int64

# %%
data = data.dropna(subset=['Music effects'])

# %%
data = data.drop(["Permissions"],axis=1)

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
fav_genre_bpm_mean = data.groupby('Fav genre')['BPM'].mean()
fav_genre_bpm_mean
# Out:
# Fav genre
# Classical           1.145750e+02
# Country             1.101905e+02
# EDM                 1.475000e+02
# Folk                1.097200e+02
# Gospel              8.925000e+01
# Hip hop             1.119062e+02
# Jazz                1.244737e+02
# K pop               1.294783e+02
# Latin               1.225000e+02
# Lofi                1.143000e+02
# Metal               1.391026e+02
# Pop                 1.189072e+02
# R&B                 1.141667e+02
# Rap                 1.271000e+02
# Rock                1.240867e+02
# Video game music    2.702714e+07
# Name: BPM, dtype: float64

# %%
fav_genre_bpm_dict = fav_genre_bpm_mean.to_dict()
fav_genre_bpm_dict
# Out:
# {'Classical': 114.575,
#  'Country': 110.19047619047619,
#  'EDM': 147.5,
#  'Folk': 109.72,
#  'Gospel': 89.25,
#  'Hip hop': 111.90625,
#  'Jazz': 124.47368421052632,
#  'K pop': 129.47826086956522,
#  'Latin': 122.5,
#  'Lofi': 114.3,
#  'Metal': 139.10256410256412,
#  'Pop': 118.90721649484536,
#  'R&B': 114.16666666666667,
#  'Rap': 127.1,
#  'Rock': 124.08666666666667,
#  'Video game music': 27027143.513513513}

# %%
def fill_bpm(row):
    if pd.isnull(row['BPM']):
        return fav_genre_bpm_dict.get(row['Fav genre'], data['BPM'].mean())
    return row['BPM']

# %%
data['BPM'] = data.apply(fill_bpm, axis=1)

# %%
null_counts = data.isnull().sum()
print("Null counts")
null_counts[null_counts > 0]
# Out:
# Null counts
# Primary streaming service    1
# While working                2
# Instrumentalist              3
# Foreign languages            3
# dtype: int64

# %%
missing_val_cols = null_counts[null_counts > 0].to_dict().keys()
missing_val_cols
# Out:
# dict_keys(['Primary streaming service', 'While working', 'Instrumentalist', 'Foreign languages'])

# %%
for col in missing_val_cols:
    data[col] = data[col].fillna(data[col].mode()[0])

# %%
yes_or_no_cols = ['While working', 'Instrumentalist', 'Composer', 'Exploratory', 'Foreign languages']

for col in yes_or_no_cols:
    data[col] = data[col].map({'Yes': 1, 'No': 0})

# %%
data = pd.get_dummies(data, columns=['Primary streaming service'], prefix='Streaming Service', drop_first=False)
data = pd.get_dummies(data, columns=['Fav genre'], prefix='Fav Genre', drop_first=False)

# %%
data['Frequency [Pop]'].value_counts()
# Out:
# Frequency [Pop]
# Very frequently    274
# Sometimes          257
# Rarely             142
# Never               55
# Name: count, dtype: int64

# %%
frequency_cols = [col for col in data.columns if col.startswith('Frequency')]
frequency_cols
# Out:
# ['Frequency [Classical]',
#  'Frequency [Country]',
#  'Frequency [EDM]',
#  'Frequency [Folk]',
#  'Frequency [Gospel]',
#  'Frequency [Hip hop]',
#  'Frequency [Jazz]',
#  'Frequency [K pop]',
#  'Frequency [Latin]',
#  'Frequency [Lofi]',
#  'Frequency [Metal]',
#  'Frequency [Pop]',
#  'Frequency [R&B]',
#  'Frequency [Rap]',
#  'Frequency [Rock]',
#  'Frequency [Video game music]']

# %%
frequency_value_map = {
    'Very frequently': 3,
    'Sometimes': 2,
    'Rarely': 1,
    'Never': 0
}

for col in frequency_cols:
    data[col] = data[col].map(frequency_value_map)
data['Frequency [Pop]']
# Out:
# 2      1
# 3      2
# 4      2
# 5      3
# 6      1
#       ..
# 731    3
# 732    3
# 733    2
# 734    0
# 735    2
# Name: Frequency [Pop], Length: 728, dtype: int64

# %%
le = LabelEncoder()
data['Music effects'] = le.fit_transform(data['Music effects'])

# %%
data.head()
# Out:
#             Timestamp   Age  Hours per day  While working  Instrumentalist  \
# 2  8/27/2022 21:28:18  18.0            4.0              0                0
# 3  8/27/2022 21:40:40  61.0            2.5              1                0
# 4  8/27/2022 21:54:47  18.0            4.0              1                0
# 5  8/27/2022 21:56:50  18.0            5.0              1                1
# 6  8/27/2022 22:00:29  18.0            3.0              1                1
#
#    Composer  Exploratory  Foreign languages    BPM  Frequency [Classical]  \
# 2         0            0                  1  132.0                      0
# 3         1            1                  1   84.0                      2
# 4         0            1                  0  107.0                      0
# 5         1            1                  1   86.0                      1
# 6         0            1                  1   66.0                      2
#
#    ...  Fav Genre_Jazz  Fav Genre_K pop  Fav Genre_Latin  Fav Genre_Lofi  \
# 2  ...           False            False            False           False
# 3  ...            True            False            False           False
# 4  ...           False            False            False           False
# 5  ...            True            False            False           False
# 6  ...           False            False            False           False
#
#    Fav Genre_Metal  Fav Genre_Pop  Fav Genre_R&B  Fav Genre_Rap  \
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False           True          False
# 5            False          False          False          False
# 6            False          False          False          False
#
#    Fav Genre_Rock  Fav Genre_Video game music
# 2           False                        True
# 3           False                       False
# 4           False                       False
# 5           False                       False
# 6           False                        True
#
# [5 rows x 52 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 728 entries, 2 to 735
# Data columns (total 52 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Timestamp                                            728 non-null    object
#  1   Age                                                  728 non-null    float64
#  2   Hours per day                                        728 non-null    float64
#  3   While working                                        728 non-null    int64
#  4   Instrumentalist                                      728 non-null    int64
#  5   Composer                                             728 non-null    int64
#  6   Exploratory                                          728 non-null    int64
#  7   Foreign languages                                    728 non-null    int64
#  8   BPM                                                  728 non-null    float64
#  9   Frequency [Classical]                                728 non-null    int64
#  10  Frequency [Country]                                  728 non-null    int64
#  11  Frequency [EDM]                                      728 non-null    int64
#  12  Frequency [Folk]                                     728 non-null    int64
#  13  Frequency [Gospel]                                   728 non-null    int64
#  14  Frequency [Hip hop]                                  728 non-null    int64
#  15  Frequency [Jazz]                                     728 non-null    int64
#  16  Frequency [K pop]                                    728 non-null    int64
#  17  Frequency [Latin]                                    728 non-null    int64
#  18  Frequency [Lofi]                                     728 non-null    int64
#  19  Frequency [Metal]                                    728 non-null    int64
#  20  Frequency [Pop]                                      728 non-null    int64
#  21  Frequency [R&B]                                      728 non-null    int64
#  22  Frequency [Rap]                                      728 non-null    int64
#  23  Frequency [Rock]                                     728 non-null    int64
#  24  Frequency [Video game music]                         728 non-null    int64
#  25  Anxiety                                              728 non-null    float64
#  26  Depression                                           728 non-null    float64
#  27  Insomnia                                             728 non-null    float64
#  28  OCD                                                  728 non-null    float64
#  29  Music effects                                        728 non-null    int64
#  30  Streaming Service_Apple Music                        728 non-null    bool
#  31  Streaming Service_I do not use a streaming service.  728 non-null    bool
#  32  Streaming Service_Other streaming service            728 non-null    bool
#  33  Streaming Service_Pandora                            728 non-null    bool
#  34  Streaming Service_Spotify                            728 non-null    bool
#  35  Streaming Service_YouTube Music                      728 non-null    bool
#  36  Fav Genre_Classical                                  728 non-null    bool
#  37  Fav Genre_Country                                    728 non-null    bool
#  38  Fav Genre_EDM                                        728 non-null    bool
#  39  Fav Genre_Folk                                       728 non-null    bool
#  40  Fav Genre_Gospel                                     728 non-null    bool
#  41  Fav Genre_Hip hop                                    728 non-null    bool
#  42  Fav Genre_Jazz                                       728 non-null    bool
#  43  Fav Genre_K pop                                      728 non-null    bool
#  44  Fav Genre_Latin                                      728 non-null    bool
#  45  Fav Genre_Lofi                                       728 non-null    bool
#  46  Fav Genre_Metal                                      728 non-null    bool
#  47  Fav Genre_Pop                                        728 non-null    bool
#  48  Fav Genre_R&B                                        728 non-null    bool
#  49  Fav Genre_Rap                                        728 non-null    bool
#  50  Fav Genre_Rock                                       728 non-null    bool
#  51  Fav Genre_Video game music                           728 non-null    bool
# dtypes: bool(22), float64(7), int64(22), object(1)
# memory usage: 192.0+ KB

# %%
data.describe()
# Out:
#               Age  Hours per day  While working  Instrumentalist    Composer  \
# count  728.000000     728.000000     728.000000       728.000000  728.000000
# mean    25.143054       3.591415       0.789835         0.318681    0.171703
# std     11.919787       3.038554       0.407706         0.466286    0.377382
# min     10.000000       0.000000       0.000000         0.000000    0.000000
# 25%     18.000000       2.000000       1.000000         0.000000    0.000000
# 50%     21.000000       3.000000       1.000000         0.000000    0.000000
# 75%     28.000000       5.000000       1.000000         1.000000    0.000000
# max     89.000000      24.000000       1.000000         1.000000    1.000000
#
#        Exploratory  Foreign languages           BPM  Frequency [Classical]  \
# count   728.000000         728.000000  7.280000e+02             728.000000
# mean      0.715659           0.553571  1.633624e+06               1.336538
# std       0.451410           0.497464  3.714669e+07               0.991399
# min       0.000000           0.000000  0.000000e+00               0.000000
# 25%       0.000000           0.000000  1.040000e+02               1.000000
# 50%       1.000000           1.000000  1.200000e+02               1.000000
# 75%       1.000000           1.000000  1.400000e+02               2.000000
# max       1.000000           1.000000  1.000000e+09               3.000000
#
#        Frequency [Country]  ...  Frequency [Pop]  Frequency [R&B]  \
# count           728.000000  ...       728.000000       728.000000
# mean              0.818681  ...         2.030220         1.255495
# std               0.923532  ...         0.934833         1.061051
# min               0.000000  ...         0.000000         0.000000
# 25%               0.000000  ...         1.000000         0.000000
# 50%               1.000000  ...         2.000000         1.000000
# 75%               1.000000  ...         3.000000         2.000000
# max               3.000000  ...         3.000000         3.000000
#
#        Frequency [Rap]  Frequency [Rock]  Frequency [Video game music]  \
# count       728.000000        728.000000                    728.000000
# mean          1.336538          2.074176                      1.251374
# std           1.054595          1.033147                      1.071706
# min           0.000000          0.000000                      0.000000
# 25%           0.000000          1.000000                      0.000000
# 50%           1.000000          2.000000                      1.000000
# 75%           2.000000          3.000000                      2.000000
# max           3.000000          3.000000                      3.000000
#
#           Anxiety  Depression    Insomnia         OCD  Music effects
# count  728.000000  728.000000  728.000000  728.000000     728.000000
# mean     5.849588    4.803571    3.753434    2.645604       0.278846
# std      2.787469    3.024069    3.095676    2.844204       0.498132
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      4.000000    2.000000    1.000000    0.000000       0.000000
# 50%      6.000000    5.000000    3.000000    2.000000       0.000000
# 75%      8.000000    7.000000    6.000000    5.000000       1.000000
# max     10.000000   10.000000   10.000000   10.000000       2.000000
#
# [8 rows x 29 columns]

# %%
null_counts = data.isnull().sum()
print("Null counts")
null_counts[null_counts > 0]
# Out:
# Null counts
# Series([], dtype: int64)
